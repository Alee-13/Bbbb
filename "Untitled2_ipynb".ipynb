# %% [markdown]
# <a href="https://colab.research.google.com/github/Alee-13/Bbbb/blob/main/%22Untitled2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![зад 1.png](data:image/png;base64,...)

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
name = input("Как Вас зовут? ")
print("Привет,", name)
# Out:
# Как Вас зовут? Ахлиддин
# Привет, Ахлиддин

# %%
name = input("Как Вас зовут? ")
print("Привет,", name)
4 + 1
# Out:
# Как Вас зовут? Ахлиддин
# Привет, Ахлиддин
# 5

# %% [markdown]
# При написании 4 + 1 в конце ничего не дает, так как нужна команда print() для IDLE, а для google colab она автоматически выводит результат операции как 5, так как компилятор сама определяет как вывод операции

# %%
4 + 1
print(2 * 2)
print("Здравствуйте!")
# Out:
# 4
# Здравствуйте!

# %%
print("Здравствуйте!"
# Out:
#   File "<ipython-input-6-201326dfd287>", line 1
#     print("Здравствуйте!"
#                          ^
# SyntaxError: incomplete input

# %%
print"Здравствуйте!")
# Out:
#   File "<ipython-input-7-f27487219eac>", line 1
#     print"Здравствуйте!")
#                         ^
# SyntaxError: unmatched ')'

# %%
print('Здравствуйте!')
# Out:
# Здравствуйте!

# %%
print "Здравствуйте!"
# Out:
#   File "<ipython-input-9-1f60466816e6>", line 1
#     print "Здравствуйте!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# При удалении одной/двух скобок выдает ошибку и не запускается. При смене на одинарные скобки запускается, также и на IDLE

# %% [markdown]
# ЗАДАНИЕ 2

# %% [markdown]
# ![зад 2.png](data:image/png;base64,...)

# %% [markdown]
# ЗАДАНИЕ 3

# %% [markdown]
# ![Снимок экрана (11).png](data:image/png;base64,...)
